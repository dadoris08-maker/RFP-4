# %% [markdown]
# # Mole Classifier:
# This notebook trains a simple image classifier using Keras to tell the difference between benign moles and melanoma.

# %% [markdown]
# ## Step 0: Install Neural Net Libraries

# %%
import sys
# !{sys.executable} -m pip install tensorflow
import tensorflow as tf
print(tf.__version__)

print("done")
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: /usr/share/pip-wheels
# Collecting tensorflow
#   Obtaining dependency information for tensorflow from https://files.pythonhosted.org/packages/26/a1/23b9b39c046c723db63a1c2c93397703efa3400a36f98d9c717b473aafb8/tensorflow-2.21.0-cp311-cp311-manylinux_2_27_x86_64.whl.metadata
#   Downloading tensorflow-2.21.0-cp311-cp311-manylinux_2_27_x86_64.whl.metadata (4.4 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /home/3117371a-11f6-4a7a-83fa-f3df3a583ebd/.local/lib/python3.11/site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /home/3117371a-11f6-4a7a-83fa-f3df3a583ebd/.local/lib/python3.11/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=25.9.23 in /home/3117371a-11f6-4a7a-83fa-f3df3a583ebd/.local/lib/python3.11/site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /home/3117371a-11f6-4a7a-83fa-f3df3a583ebd/.local/lib/python3.11/site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /home/3117371a-11f6-4a7a-83fa-f3df3a583ebd/.local/lib/python3.11/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/3117371a-11f6-4a7a-83fa-f3df3a583ebd/.local/lib/python3.11/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /home/3117371a-11f6-4a7a-83fa-f3df3a583ebd/.local/lib/python3.11/site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from tensorflow) (23.1)
# Requirement already satisfied: protobuf<8.0.0,>=6.31.1 in /home/3117371a-11f6-4a7a-83fa-f3df3a583ebd/.local/lib/python3.11/site-packages (from tensorflow) (7.34.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from tensorflow) (2.31.0)
# Requirement already satisfied: setuptools in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from tensorflow) (68.0.0)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/3117371a-11f6-4a7a-83fa-f3df3a583ebd/.local/lib/python3.11/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /home/3117371a-11f6-4a7a-83fa-f3df3a583ebd/.local/lib/python3.11/site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/3117371a-11f6-4a7a-83fa-f3df3a583ebd/.local/lib/python3.11/site-packages (from tensorflow) (1.78.0)
# Collecting keras>=3.12.0 (from tensorflow)
#   Obtaining dependency information for keras>=3.12.0 from https://files.pythonhosted.org/packages/28/b5/ea85873abc99dc64a7a27ff1a8dbfdc7dbb57d4e5d1a423abc11217af4f1/keras-3.13.2-py3-none-any.whl.metadata
#   Downloading keras-3.13.2-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy>=1.26.0 in /home/3117371a-11f6-4a7a-83fa-f3df3a583ebd/.local/lib/python3.11/site-packages (from tensorflow) (2.4.3)
# Requirement already satisfied: h5py<3.15.0,>=3.11.0 in /home/3117371a-11f6-4a7a-83fa-f3df3a583ebd/.local/lib/python3.11/site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /home/3117371a-11f6-4a7a-83fa-f3df3a583ebd/.local/lib/python3.11/site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow) (0.38.4)
# Requirement already satisfied: rich in /home/3117371a-11f6-4a7a-83fa-f3df3a583ebd/.local/lib/python3.11/site-packages (from keras>=3.12.0->tensorflow) (14.3.3)
# Requirement already satisfied: namex in /home/3117371a-11f6-4a7a-83fa-f3df3a583ebd/.local/lib/python3.11/site-packages (from keras>=3.12.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /home/3117371a-11f6-4a7a-83fa-f3df3a583ebd/.local/lib/python3.11/site-packages (from keras>=3.12.0->tensorflow) (0.19.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (2023.7.22)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from rich->keras>=3.12.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from rich->keras>=3.12.0->tensorflow) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.12.0->tensorflow) (0.1.0)
# Downloading tensorflow-2.21.0-cp311-cp311-manylinux_2_27_x86_64.whl (572.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 572.4/572.4 MB ? eta 0:00:00 eta 0:00:0136m0:00:02m
# Downloading keras-3.13.2-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 9.9 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: keras, tensorflow

# %%
import sys
# !{sys.executable} -m pip uninstall tensorflow keras -y
# !pip cache purge
# Out:
# WARNING: Skipping tensorflow as it is not installed.
# WARNING: Skipping keras as it is not installed.
# WARNING: No matching packages
# Files removed: 0

# %% [markdown]
# ### Don't forget to restart your kernal at this point.

# %% [markdown]
# ## Step 1: Import Libraries

# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt

print("Done")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import tensorflow as tf
#       2 from tensorflow import keras
#       3 import matplotlib.pyplot as plt
#
# File ~/.local/lib/python3.11/site-packages/tensorflow/__init__.py:40
#      37 _os.environ.setdefault("ENABLE_RUNTIME_UPTIME_TELEMETRY", "1")
#      39 # Do not remove this line; See https://github.com/tensorflow/tensorflow/issues/42596
# ---> 40 from tensorflow.python import pywrap_tensorflow as _pywrap_tensorflow  # pylint: disable=unused-import
#      41 from tensorflow.python.tools import module_util as _module_util
#      42 from tensorflow.python.util.lazy_loader import KerasLazyLoader as _KerasLazyLoader
#
# ModuleNotFoundError: No module named 'tensorflow.python'

# %% [markdown]
# ## Step 2: Load the Images
#
# Keras can read images directly from folders. Each subfolder name becomes the label ("benign" or "malignant").
#
# We resize all images to 64×64 pixels so they are all the same size.

# %%
IMAGE_SIZE = (64, 64)   # resize all images to 64x64 pixels
BATCH_SIZE = 16         # process 16 images at a time

def load_data(folder_path):
    dataset = keras.utils.image_dataset_from_directory(
        folder_path,
        image_size=IMAGE_SIZE,
        batch_size=BATCH_SIZE,
        label_mode="binary"  # two classes: 0 or 1
    )
    return dataset

train_data = load_data("melanoma_cancer_dataset/train")
test_data  = load_data("melanoma_cancer_dataset/test")

# Print the class names Keras found
print("Classes:", train_data.class_names)

# %% [markdown]
# ## Step 3: Preview Some Images
#
# Let's look at a few images so we know the data loaded correctly.

# %%
def show_sample_images(dataset):
    class_names = dataset.class_names
    images, labels = next(iter(dataset))  # grab the first batch

    plt.figure(figsize=(10, 4))
    for i in range(6):
        plt.subplot(2, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        label_index = int(labels[i].numpy())
        plt.title(class_names[label_index])
        plt.axis("off")
    plt.tight_layout()
    plt.show()

show_sample_images(train_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 15
#      12     plt.tight_layout()
#      13     plt.show()
# ---> 15 show_sample_images(train_data)
#
# NameError: name 'train_data' is not defined

# %% [markdown]
# ## Step 4: Normalize the Images
#
# Pixel values go from 0–255. We scale them to 0–1 so the model trains more smoothly.

# %%
def normalize(image, label):
    image = tf.cast(image, tf.float32) / 255.0
    return image, label

train_data = train_data.map(normalize)
test_data  = test_data.map(normalize)

# %% [markdown]
# ## Step 5: Build the Model
#
# Our neural network has three parts:
# 1. **Convolutional layers** — detect shapes and textures in the image
# 2. **Flatten** — turn the 2D feature map into a 1D list
# 3. **Dense layers** — make the final benign/melanoma decision

# %%
def build_model():
    model = keras.Sequential([
        # --- Feature detection ---
        keras.layers.Conv2D(16, (3, 3), activation="relu", input_shape=(64, 64, 3)),
        keras.layers.MaxPooling2D(),

        keras.layers.Conv2D(32, (3, 3), activation="relu"),
        keras.layers.MaxPooling2D(),

        # --- Decision making ---
        keras.layers.Flatten(),
        keras.layers.Dense(64, activation="relu"),
        keras.layers.Dense(1, activation="sigmoid")  # output: 0 = benign, 1 = malignant
    ])

    model.compile(
        optimizer="adam",
        loss="binary_crossentropy",
        metrics=["accuracy"]
    )

    return model

model = build_model()
model.summary()

# %% [markdown]
# ## Step 6: Train the Model
#
# We train for **5 epochs** (5 passes through the training data). This keeps training fast while still showing the model learning.

# %%
EPOCHS = 5

history = model.fit(
    train_data,
    epochs=EPOCHS,
    validation_data=test_data
)

# %% [markdown]
# ## Step 7: Plot Training Results
#
# Let's see how accuracy and loss changed over each epoch.

# %%
def plot_training(history):
    epochs = range(1, len(history.history["accuracy"]) + 1)

    plt.figure(figsize=(12, 4))

    # Accuracy plot
    plt.subplot(1, 2, 1)
    plt.plot(epochs, history.history["accuracy"],     label="Train Accuracy")
    plt.plot(epochs, history.history["val_accuracy"], label="Test Accuracy")
    plt.title("Accuracy Over Time")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.legend()

    # Loss plot
    plt.subplot(1, 2, 2)
    plt.plot(epochs, history.history["loss"],     label="Train Loss")
    plt.plot(epochs, history.history["val_loss"], label="Test Loss")
    plt.title("Loss Over Time")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()

    plt.tight_layout()
    plt.show()

plot_training(history)

# %% [markdown]
# ## Step 8: Evaluate on the Test Set

# %%
def evaluate_model(model, test_data):
    loss, accuracy = model.evaluate(test_data)
    print(f"Test Loss:     {loss:.4f}")
    print(f"Test Accuracy: {accuracy:.2%}")

evaluate_model(model, test_data)

# %% [markdown]
# ## Step 9: Predict on Individual Images
#
# Let's look at a few test images and see what the model predicts.

# %%
def show_predictions(model, dataset, num_images=6):
    class_names = dataset.class_names
    images, true_labels = next(iter(dataset))  # grab one batch

    predictions = model.predict(images)

    plt.figure(figsize=(12, 5))
    for i in range(num_images):
        plt.subplot(2, 3, i + 1)
        plt.imshow(images[i].numpy())

        predicted_index = int(predictions[i][0] > 0.5)  # 0 or 1
        true_index      = int(true_labels[i].numpy())

        predicted_label = class_names[predicted_index]
        true_label      = class_names[true_index]

        color = "green" if predicted_index == true_index else "red"
        plt.title(f"Pred: {predicted_label}\nTrue: {true_label}", color=color)
        plt.axis("off")

    plt.tight_layout()
    plt.show()

show_predictions(model, test_data)
