# %% [markdown]
# # Mole Classifier:
# This notebook trains a simple image classifier using Keras to tell the difference between benign moles and melanoma.

# %% [markdown]
# ## Step 0: Install Neural Net Libraries

# %%
import sys
# !{sys.executable} -m pip install tensorflow
import tensorflow as tf
print(tf.__version__)

print("done")
# Out:
# Requirement already satisfied: tensorflow in c:\users\telliott9\appdata\local\anaconda3\lib\site-packages (2.21.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\telliott9\appdata\local\anaconda3\lib\site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\telliott9\appdata\local\anaconda3\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=25.9.23 in c:\users\telliott9\appdata\local\anaconda3\lib\site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\telliott9\appdata\local\anaconda3\lib\site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\telliott9\appdata\local\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\telliott9\appdata\local\anaconda3\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\telliott9\appdata\local\anaconda3\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\telliott9\appdata\local\anaconda3\lib\site-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf<8.0.0,>=6.31.1 in c:\users\telliott9\appdata\local\anaconda3\lib\site-packages (from tensorflow) (7.34.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\telliott9\appdata\local\anaconda3\lib\site-packages (from tensorflow) (2.32.5)
# Requirement already satisfied: setuptools in c:\users\telliott9\appdata\local\anaconda3\lib\site-packages (from tensorflow) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\telliott9\appdata\local\anaconda3\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\telliott9\appdata\local\anaconda3\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\telliott9\appdata\local\anaconda3\lib\site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\telliott9\appdata\local\anaconda3\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\telliott9\appdata\local\anaconda3\lib\site-packages (from tensorflow) (1.78.0)
# Requirement already satisfied: keras>=3.12.0 in c:\users\telliott9\appdata\local\anaconda3\lib\site-packages (from tensorflow) (3.13.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\telliott9\appdata\local\anaconda3\lib\site-packages (from tensorflow) (2.3.5)
# Requirement already satisfied: h5py<3.15.0,>=3.11.0 in c:\users\telliott9\appdata\local\anaconda3\lib\site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\telliott9\appdata\local\anaconda3\lib\site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\telliott9\appdata\local\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\telliott9\appdata\local\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\telliott9\appdata\local\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\telliott9\appdata\local\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.11.12)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\telliott9\appdata\local\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in c:\users\telliott9\appdata\local\anaconda3\lib\site-packages (from keras>=3.12.0->tensorflow) (14.2.0)
# Requirement already satisfied: namex in c:\users\telliott9\appdata\local\anaconda3\lib\site-packages (from keras>=3.12.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in c:\users\telliott9\appdata\local\anaconda3\lib\site-packages (from keras>=3.12.0->tensorflow) (0.19.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\telliott9\appdata\local\anaconda3\lib\site-packages (from rich->keras>=3.12.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\telliott9\appdata\local\anaconda3\lib\site-packages (from rich->keras>=3.12.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\telliott9\appdata\local\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.12.0->tensorflow) (0.1.2)
# 2.21.0
# done

# %%
import sys
# !{sys.executable} -m pip uninstall tensorflow keras -y
# !pip cache purge

# %% [markdown]
# ### Don't forget to restart your kernal at this point.

# %% [markdown]
# ## Step 1: Import Libraries

# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt

print("Done")
# Out:
# Done

# %% [markdown]
# ## Step 2: Load the Images
#
# Keras can read images directly from folders. Each subfolder name becomes the label ("benign" or "malignant").
#
# We resize all images to 64×64 pixels so they are all the same size.

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\telliott9\Documents\monkeypox

# %%
IMAGE_SIZE = (64, 64)   # resize all images to 64x64 pixels
BATCH_SIZE = 16         # process 16 images at a time

def load_data(folder_path):
    dataset = keras.utils.image_dataset_from_directory(
        folder_path,
        image_size=IMAGE_SIZE,
        batch_size=BATCH_SIZE,
        label_mode="binary"  # two classes: 0 or 1
    )
    return dataset

train_data = load_data("monkeypox_dataset/train")
test_data  = load_data("monkeypox_dataset/test")

# Print the class names Keras found
print("Classes:", train_data.class_names)
# Out:
# Found 4493 files belonging to 2 classes.
# Found 21 files belonging to 2 classes.
# Classes: ['Monkeypox', 'Normal']

# %% [markdown]
# ## Step 3: Preview Some Images
#
# Let's look at a few images so we know the data loaded correctly.

# %%
def show_sample_images(dataset):
    class_names = dataset.class_names
    images, labels = next(iter(dataset))  # grab the first batch

    plt.figure(figsize=(10, 4))
    for i in range(6):
        plt.subplot(2, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        label_index = int(labels[i].numpy())
        plt.title(class_names[label_index])
        plt.axis("off")
    plt.tight_layout()
    plt.show()

show_sample_images(train_data)
# Out:
# C:\Users\telliott9\AppData\Local\Temp\ipykernel_31284\1350892821.py:9: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   label_index = int(labels[i].numpy())

# %% [markdown]
# ## Step 4: Normalize the Images
#
# Pixel values go from 0–255. We scale them to 0–1 so the model trains more smoothly.

# %%
def normalize(image, label):
    image = tf.cast(image, tf.float32) / 255.0
    return image, label
    
class_names = train_data.class_names
train_data = train_data.map(normalize)
test_data  = test_data.map(normalize)

# %% [markdown]
# ## Step 5: Build the Model
#
# Our neural network has three parts:
# 1. **Convolutional layers** — detect shapes and textures in the image
# 2. **Flatten** — turn the 2D feature map into a 1D list
# 3. **Dense layers** — make the final benign/melanoma decision

# %%
def build_model():
    model = keras.Sequential([
        # --- Feature detection ---
        keras.layers.Conv2D(16, (3, 3), activation="relu", input_shape=(64, 64, 3)),
        keras.layers.MaxPooling2D(),

        keras.layers.Conv2D(32, (3, 3), activation="relu"),
        keras.layers.MaxPooling2D(),

        # --- Decision making ---
        keras.layers.Flatten(),
        keras.layers.Dense(64, activation="relu"),
        keras.layers.Dense(1, activation="sigmoid")  # output: 0 = benign, 1 = malignant
    ])

    model.compile(
        optimizer="adam",
        loss="binary_crossentropy",
        metrics=["accuracy"]
    )

    return model

model = build_model()
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_4 (Conv2D)               │ (None, 62, 62, 16)     │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 31, 31, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 29, 29, 32)     │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 14, 14, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 6272)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 64)             │       401,472 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 406,625 (1.55 MB)
#  Trainable params: 406,625 (1.55 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Step 6: Train the Model
#
# We train for **5 epochs** (5 passes through the training data). This keeps training fast while still showing the model learning.

# %%
EPOCHS = 5

history = model.fit(
    train_data,
    epochs=EPOCHS,
    validation_data=test_data
)
# Out:
# Epoch 1/5
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.7171 - loss: 0.5372 - val_accuracy: 0.6667 - val_loss: 0.9075
# Epoch 2/5
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.8442 - loss: 0.3511 - val_accuracy: 0.8095 - val_loss: 0.6856
# Epoch 3/5
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.8756 - loss: 0.2896 - val_accuracy: 0.8571 - val_loss: 0.3978
# Epoch 4/5
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.9130 - loss: 0.2191 - val_accuracy: 0.8095 - val_loss: 0.3043
# Epoch 5/5
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.9210 - loss: 0.1977 - val_accuracy: 0.8095 - val_loss: 0.3343

# %% [markdown]
# ## Step 7: Plot Training Results
#
# Let's see how accuracy and loss changed over each epoch.

# %%
def plot_training(history):
    epochs = range(1, len(history.history["accuracy"]) + 1)

    plt.figure(figsize=(12, 4))

    # Accuracy plot
    plt.subplot(1, 2, 1)
    plt.plot(epochs, history.history["accuracy"],     label="Train Accuracy")
    plt.plot(epochs, history.history["val_accuracy"], label="Test Accuracy")
    plt.title("Accuracy Over Time")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.legend()

    # Loss plot
    plt.subplot(1, 2, 2)
    plt.plot(epochs, history.history["loss"],     label="Train Loss")
    plt.plot(epochs, history.history["val_loss"], label="Test Loss")
    plt.title("Loss Over Time")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()

    plt.tight_layout()
    plt.show()

plot_training(history)

# %% [markdown]
# ## Step 8: Evaluate on the Test Set

# %%
def evaluate_model(model, test_data):
    loss, accuracy = model.evaluate(test_data)
    print(f"Test Loss:     {loss:.4f}")
    print(f"Test Accuracy: {accuracy:.2%}")

evaluate_model(model, test_data)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8095 - loss: 0.3343
# Test Loss:     0.3343
# Test Accuracy: 80.95%

# %% [markdown]
# ## Step 9: Predict on Individual Images
#
# Let's look at a few test images and see what the model predicts.

# %%
def show_predictions(model, dataset, num_images=6):
    #class_names = dataset.class_names
    images, true_labels = next(iter(dataset))  # grab one batch

    predictions = model.predict(images)

    plt.figure(figsize=(12, 5))
    for i in range(num_images):
        plt.subplot(2, 3, i + 1)
        plt.imshow(images[i].numpy())

        predicted_index = int(predictions[i][0] > 0.5)  # 0 or 1
        true_index      = int(true_labels[i].numpy())

        predicted_label = class_names[predicted_index]
        true_label      = class_names[true_index]

        color = "green" if predicted_index == true_index else "red"
        plt.title(f"Pred: {predicted_label}\nTrue: {true_label}", color=color)
        plt.axis("off")

    plt.tight_layout()
    plt.show()

show_predictions(model, test_data)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# C:\Users\telliott9\AppData\Local\Temp\ipykernel_31284\689778916.py:13: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   true_index      = int(true_labels[i].numpy())
